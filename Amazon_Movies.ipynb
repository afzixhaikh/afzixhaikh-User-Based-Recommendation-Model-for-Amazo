# %%
#First we import the basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#We read the movie data
data = pd.read_csv("Amazon - Movies and TV Ratings.csv")

# %%
data.shape
# Out:
# (4848, 207)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4848 entries, 0 to 4847
# Columns: 207 entries, user_id to Movie206
# dtypes: float64(206), object(1)
# memory usage: 7.7+ MB

# %%
data.columns
# Out:
# Index(['user_id', 'Movie1', 'Movie2', 'Movie3', 'Movie4', 'Movie5', 'Movie6',
#        'Movie7', 'Movie8', 'Movie9',
#        ...
#        'Movie197', 'Movie198', 'Movie199', 'Movie200', 'Movie201', 'Movie202',
#        'Movie203', 'Movie204', 'Movie205', 'Movie206'],
#       dtype='object', length=207)

# %%
#We see the basic structure of the dataset
data.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# ...

# %%
data.sample(10)
# Out:
#              user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 1057  A1ZAN7KBME97B3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 839   A1S3F7ZM1IS8K6     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1160   ACIBQ6BQ6AWEV     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 772   A20VTMEUX1RLFZ     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 149    AQPESGTO73D0T     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 29    A2T8A34ZSAXGHA     NaN     NaN     NaN     NaN     2.0     NaN     NaN
# 357   A27NOR6IOINAKO     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3489  A3P68RUVJ4HHPN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4571  A1R2V0XB7T7D5A     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1969  A3QF1VDYTLX69S     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#       Movie8  Movie9  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# ...

# %%
data.describe()
# Out:
#        Movie1  Movie2  Movie3  Movie4     Movie5  Movie6  Movie7  Movie8  \
# count     1.0     1.0     1.0     2.0  29.000000     1.0     1.0     1.0
# mean      5.0     5.0     2.0     5.0   4.103448     4.0     5.0     5.0
# std       NaN     NaN     NaN     0.0   1.496301     NaN     NaN     NaN
# min       5.0     5.0     2.0     5.0   1.000000     4.0     5.0     5.0
# 25%       5.0     5.0     2.0     5.0   4.000000     4.0     5.0     5.0
# 50%       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
# 75%       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
# max       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
#
#        Movie9  Movie10  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# count     1.0      1.0  ...  5.000000       2.0       1.0  8.000000  3.000000
# mean      5.0      5.0  ...  3.800000       5.0       5.0  4.625000  4.333333
# ...

# %%
#Movie 127 is the movie with maximum views
(data.isnull().sum()).sort_values()[:5]
# Out:
# user_id        0
# Movie127    2535
# Movie140    4270
# Movie16     4528
# Movie103    4576
# dtype: int64

# %%
data['Movie127'].count()
# Out:
# 2313

# %%
#Logically movie 127 has the highest sum of ratings too
data.drop("user_id", axis=1).sum().sort_values(ascending=False)[:1]
# Out:
# Movie127    9511.0
# dtype: float64

# %%
data.drop('user_id', axis=1).sum()
# Out:
# Movie1        5.0
# Movie2        5.0
# Movie3        2.0
# Movie4       10.0
# Movie5      119.0
#             ...
# Movie202     26.0
# Movie203      3.0
# Movie204     35.0
# Movie205    162.0
# Movie206     64.0
# Length: 206, dtype: float64

# %%
#These are the top 5 movies with highest average rating
data.drop('user_id', axis=1).mean().sort_values(ascending=False)[:5]
# Out:
# Movie1     5.0
# Movie66    5.0
# Movie76    5.0
# Movie75    5.0
# Movie74    5.0
# dtype: float64

# %%
data.drop('user_id', axis=1).count()
# Out:
# Movie1       1
# Movie2       1
# Movie3       1
# Movie4       2
# Movie5      29
#             ..
# Movie202     6
# Movie203     1
# Movie204     8
# Movie205    35
# Movie206    13
# Length: 206, dtype: int64

# %%
#These are the top 5 movies with least audience
data.drop('user_id', axis=1).count().sort_values()[:5]
# Out:
# Movie1      1
# Movie71     1
# Movie145    1
# Movie69     1
# Movie68     1
# dtype: int64

# %%
#These are the average rating of all movies
data.drop('user_id', axis=1).mean()
# Out:
# Movie1      5.000000
# Movie2      5.000000
# Movie3      2.000000
# Movie4      5.000000
# Movie5      4.103448
#               ...
# Movie202    4.333333
# Movie203    3.000000
# Movie204    4.375000
# Movie205    4.628571
# Movie206    4.923077
# Length: 206, dtype: float64

# %%
#now we preprocess the data for our recommendation model
data_melt=data.melt(id_vars= data.columns[0],value_vars=data.columns[1:],var_name='Movie',value_name='rating')

# %%
data_melt
# Out:
#                user_id     Movie  rating
# 0       A3R5OBKS7OM2IR    Movie1     5.0
# 1        AH3QC2PC1VTGP    Movie1     NaN
# 2       A3LKP6WPMP9UKX    Movie1     NaN
# 3        AVIY68KEPQ5ZD    Movie1     NaN
# 4       A1CV1WROP5KTTW    Movie1     NaN
# ...                ...       ...     ...
# 998683  A1IMQ9WMFYKWH5  Movie206     5.0
# 998684  A1KLIKPUF5E88I  Movie206     5.0
# 998685   A5HG6WFZLO10D  Movie206     5.0
# 998686  A3UU690TWXCG1X  Movie206     5.0
# 998687   AI4J762YI6S06  Movie206     5.0
#
# [998688 rows x 3 columns]

# %%
#we fill in the nan values with 0
data_melt = data_melt.fillna(0)

# %%
data_melt
# Out:
#                user_id     Movie  rating
# 0       A3R5OBKS7OM2IR    Movie1     5.0
# 1        AH3QC2PC1VTGP    Movie1     0.0
# 2       A3LKP6WPMP9UKX    Movie1     0.0
# 3        AVIY68KEPQ5ZD    Movie1     0.0
# 4       A1CV1WROP5KTTW    Movie1     0.0
# ...                ...       ...     ...
# 998683  A1IMQ9WMFYKWH5  Movie206     5.0
# 998684  A1KLIKPUF5E88I  Movie206     5.0
# 998685   A5HG6WFZLO10D  Movie206     5.0
# 998686  A3UU690TWXCG1X  Movie206     5.0
# 998687   AI4J762YI6S06  Movie206     5.0
#
# [998688 rows x 3 columns]

# %%
import surprise
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import train_test_split
from surprise import SVD

# %%
reader = Reader(rating_scale=(0,5))


data = Dataset.load_from_df(data_melt, reader=reader)

# %%
Xtrain, Xtest = train_test_split(data, test_size=0.2)

# %%
#We use Singular value decomposition as our model
svd = SVD()

# %%
svd.fit(Xtrain)

# %%
pred = svd.test(Xtest)

# %%
from surprise.model_selection import cross_validate

# %%
#We get a mean RMSE of 0.27
cross_validate(svd,data,measures=['RMSE'],cv=5,verbose=2)
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.2751  0.2786  0.2756  0.2726  0.2866  0.2777  0.0048
# Fit time          67.51   70.29   66.04   64.94   64.64   66.69   2.06
# Test time         3.25    3.23    2.60    2.58    2.57    2.85    0.32
# {'test_rmse': array([0.2751103 , 0.27864409, 0.2756091 , 0.27257139, 0.28659377]),
#  'fit_time': (67.50900292396545,
#   70.28899431228638,
#   66.04400134086609,
#   64.94402933120728,
#   64.64000010490417),
#  'test_time': (3.2459967136383057,
#   3.229008913040161,
#   2.603994846343994,
#   2.584972620010376,
#   2.5710034370422363)}
